# %%
import geopandas as gp

# %%
cuencas = f'../shapefiles/cuencas_hidro_new.shp'
cuencas = gp.read_file(cuencas)

# %%
cuencas.keys()
# Out:
# Index(['LAYER', 'Codigo', 'Subcuenca', 'Nombre_Sub', 'Cuenca', 'CLOSED',
#        'BORDER_STY', 'BORDER_COL', 'BORDER_WID', 'FILL_STYLE', 'geometry'],
#       dtype='object')

# %%
cuencas.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
ec = f'../shapefiles/CuencaEl Cajon.shp'
el_cajon = gp.read_file(ec)

# %%
el_cajon.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
san_antonio_GCS_MN_LINCOLN = san_antonio.copy()

# %%
san_antonio = san_antonio.to_crs(epsg=4326)

# %%
el_cajon
# Out:
#   LAYER            GM_TYPE                                           geometry
# 0     0  Unknown Area Type  POLYGON ((-64.44319 -30.92204, -64.44291 -30.9...

# %%
temp_ec = gp.GeoDataFrame({'LAYER': 'Unknown Area Type',
                           'Codigo': 59,
                           'Subcuenca': '59 - El Cajón',
                           'Nombre_Sub': 'El Cajón',
                           'Cuenca': 'Cruz del Eje', 
                           'CLOSED': 'YES',
                           'BORDER_STY': 'Solid',
                           'BORDER_COL':  'RGB(0,0,0)',
                           'BORDER_WID': 1,
                           'FILL_STYLE': 'No Fill',
                           'geometry': el_cajon['geometry']
                           })

# %%
temp_ec
# Out:
#                LAYER  Codigo      Subcuenca Nombre_Sub        Cuenca CLOSED  \
# 0  Unknown Area Type      59  59 - El Cajón   El Cajón  Cruz del Eje    YES
#
#   BORDER_STY  BORDER_COL  BORDER_WID FILL_STYLE  \
# 0      Solid  RGB(0,0,0)           1    No Fill
#
#                                             geometry
# 0  POLYGON ((-64.44319 -30.92204, -64.44291 -30.9...

# %%
new_cuencas = cuencas.append(temp_ec, ignore_index=True)

# %%
new_cuencas
# Out:
#                 LAYER Codigo                                Subcuenca  \
# 0   Unknown Area Type     01                 01-Sistema San Francisco
# 1   Unknown Area Type     02            02-Cuenca R. Quinto (Popopis)
# 2   Unknown Area Type     03                 03-Sistema A. La Punilla
# 3   Unknown Area Type     04                   04-Cuenca R. Anizacate
# 4   Unknown Area Type     05                   05-Cuenca A. La Cañada
# 5   Unknown Area Type     06                      06-Cuenca R. Saldán
# 6   Unknown Area Type     07                07-Cuenca Emb Los Molinos
# 7   Unknown Area Type     09             09-Cuenca Emb. Piedras Moras
# 8   Unknown Area Type     10                  10-Sistema Laguna del 7
# 9   Unknown Area Type     12          12-Sistema Bañados del R. Dulce
# 10  Unknown Area Type     14                      14-Sistema Morteros
# 11  Unknown Area Type     15                     15-Sistema A. El Ají
# ...

# %%
new_cuencas.to_file('../shapefiles/cuencas_hidro.shp')

# %%
geom = san_antonio.iloc[48]['geometry']

# %%
for index, key in san_antonio.iterrows():
    print(index)
    print(type(key['geometry']))
# Out:
# 0
# <class 'shapely.geometry.polygon.Polygon'>
# 1
# <class 'shapely.geometry.polygon.Polygon'>
# 2
# <class 'shapely.geometry.polygon.Polygon'>
# 3
# <class 'shapely.geometry.polygon.Polygon'>
# 4
# <class 'shapely.geometry.polygon.Polygon'>
# 5
# <class 'shapely.geometry.polygon.Polygon'>
# 6
# <class 'shapely.geometry.polygon.Polygon'>
# 7
# <class 'shapely.geometry.polygon.Polygon'>
# 8
# <class 'shapely.geometry.polygon.Polygon'>
# 9
# <class 'shapely.geometry.polygon.Polygon'>
# 10
# <class 'shapely.geometry.polygon.Polygon'>
# 11
# <class 'shapely.geometry.polygon.Polygon'>
# 12
# <class 'shapely.geometry.polygon.Polygon'>
# 13
# <class 'shapely.geometry.polygon.Polygon'>
# 14
# <class 'shapely.geometry.polygon.Polygon'>
# 15
# <class 'shapely.geometry.polygon.Polygon'>
# 16
# <class 'shapely.geometry.polygon.Polygon'>
# 17
# <class 'shapely.geometry.polygon.Polygon'>
# 18
# <class 'shapely.geometry.polygon.Polygon'>
# 19
# <class 'shapely.geometry.polygon.Polygon'>
# 20
# ...

# %%
sa0 = san_antonio.iloc[0:2,:]
sa1 = san_antonio.iloc[1,:]

# %%
a = sa0.unary_union

# %%
res_union = gp.overlay(san_antonio, how='union')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-9143546a40ad> in <module>
# ----> 1 res_union = gp.overlay(san_antonio, how='union')
#
# TypeError: overlay() missing 1 required positional argument: 'df2'

# %%
res_union.plot()

# %%
sa2 = san_antonio[:3]

# %%
res_union = gp.overlay(res_union, sa2, how='union')

# %%
res_union
# Out:
#              NAME_1  LAYER_1          GM_TYPE_1 KML_STYLE_1            NAME_2  \
# 0  Rio_SanAntonio_C  CUENCAS  Unknown Area Type       area1  Rio_SanAntonio_C
# 1               NaN      NaN                NaN         NaN           Cajon_C
# 2               NaN      NaN                NaN         NaN               NaN
#
#    LAYER_2          GM_TYPE_2 KML_STYLE_2              NAME    LAYER  \
# 0  CUENCAS  Unknown Area Type       area1  Rio_SanAntonio_C  CUENCAS
# 1  CUENCAS  Unknown Area Type      area22           Cajon_C  CUENCAS
# 2      NaN                NaN         NaN           Cajon_D  CUENCAS
#
#              GM_TYPE KML_STYLE  \
# 0  Unknown Area Type     area1
# 1  Unknown Area Type    area22
# 2  Unknown Area Type    area22
#
#                                             geometry
# 0  POLYGON ((-64.50603 -31.40734, -64.50598 -31.4...
# 1  POLYGON ((-64.75024 -31.40102, -64.75019 -31.4...
# 2  POLYGON ((-64.72899 -31.42679, -64.72894 -31.4...

# %%
sa0 = san_antonio.loc[1]

# %%
for key in range(2, 36):
    print(key)
    satemp = san_antonio.loc[key]
    sa0 = gp.overlay(sa0, satemp, how='union')
# Out:
# 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-4f95fa3367a4> in <module>
#       2     print(key)
#       3     satemp = san_antonio.loc[key]
# ----> 4     sa0 = gp.overlay(sa0, satemp, how='union')
#
# ~/anaconda3/envs/wrfcuenca3/lib/python3.8/site-packages/geopandas/tools/overlay.py in overlay(df1, df2, how, make_valid, keep_geom_type)
#     186     points = ["Point", "MultiPoint"]
#     187     for i, df in enumerate([df1, df2]):
# --> 188         poly_check = df.geom_type.isin(polys).any()
#     189         lines_check = df.geom_type.isin(lines).any()
#     190         points_check = df.geom_type.isin(points).any()
#
# ~/anaconda3/envs/wrfcuenca3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# ...

# %%
satemp
# Out:
#                NAME    LAYER            GM_TYPE KML_STYLE  \
# 0  Rio_SanAntonio_C  CUENCAS  Unknown Area Type     area1
# 1           Cajon_C  CUENCAS  Unknown Area Type    area22
# 2           Cajon_D  CUENCAS  Unknown Area Type    area22
# 3  Rio_SanAntonio_B  CUENCAS  Unknown Area Type     area1
# 4  Rio_SanAntonio_A  CUENCAS  Unknown Area Type     area1
#
#                                             geometry
# 0  POLYGON ((-64.50603 -31.40734, -64.50598 -31.4...
# 1  POLYGON ((-64.75024 -31.40102, -64.75019 -31.4...
# 2  POLYGON ((-64.72899 -31.42679, -64.72894 -31.4...
# 3  POLYGON ((-64.53537 -31.43286, -64.53532 -31.4...
# 4  POLYGON ((-64.51498 -31.44579, -64.51493 -31.4...

# %%
sa0[:3].plot()

# %%
res = serie.unary_union()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-ebf34ac03079> in <module>
# ----> 1 res = serie.unary_union()
#
# TypeError: 'MultiPolygon' object is not callable

# %%
lq = f'../shapefiles/cuenca_lq.shp'
la_quebrada = gp.read_file(lq)

# %%
la_quebrada
# Out:
#           NAME              LAYER        KML_STYLE  tessellate  \
# 0  La Quebrada  Unknown Line Type  msn_ylw-pushpin           1
#
#                                             geometry
# 0  POLYGON ((-64.35139 -31.14219, -64.35015 -31.1...

# %%
la_quebrada.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
'LAYER', 'Codigo', 'Subcuenca', 'Nombre_Sub', 'Cuenca', 'CLOSED',
       'BORDER_STY', 'BORDER_COL', 'BORDER_WID', 'FILL_STYLE', 'geometry'
# Out:
#   File "<ipython-input-143-60b20565e936>", line 2
#     'BORDER_STY', 'BORDER_COL', 'BORDER_WID', 'FILL_STYLE', 'geometry'
#     ^
# IndentationError: unexpected indent

# %%
temp_lq = gp.GeoDataFrame({'LAYER': 'Unknown Area Type',
                           'Codigo': 57,
                           'Subcuenca': '57 - La Quebrada',
                           'Nombre_Sub': 'La Quebrada',
                           'Cuenca': 'La Quebrada', 
                           'CLOSED': 'YES',
                           'BORDER_STY': 'Solid',
                           'BORDER_COL':  'RGB(0,0,0)',
                           'BORDER_WID': 1,
                           'FILL_STYLE': 'No Fill',
                           'geometry': la_quebrada['geometry']
                           })

# %%
temp_lq
# Out:
#                LAYER  Codigo         Subcuenca   Nombre_Sub       Cuenca  \
# 0  Unknown Area Type      57  57 - La Quebrada  La Quebrada  La Quebrada
#
#   CLOSED BORDER_STY  BORDER_COL  BORDER_WID FILL_STYLE  \
# 0    YES      Solid  RGB(0,0,0)           1    No Fill
#
#                                             geometry
# 0  POLYGON ((-64.35139 -31.14219, -64.35015 -31.1...

# %%
new_cuencas = cuencas.append(temp_lq)

# %%
new_cuencas
# Out:
#                 LAYER Codigo                                Subcuenca  \
# 0   Unknown Area Type     01                 01-Sistema San Francisco
# 1   Unknown Area Type     02            02-Cuenca R. Quinto (Popopis)
# 2   Unknown Area Type     03                 03-Sistema A. La Punilla
# 3   Unknown Area Type     04                   04-Cuenca R. Anizacate
# 4   Unknown Area Type     05                   05-Cuenca A. La Cañada
# 5   Unknown Area Type     06                      06-Cuenca R. Saldán
# 6   Unknown Area Type     07                07-Cuenca Emb Los Molinos
# 7   Unknown Area Type     09             09-Cuenca Emb. Piedras Moras
# 8   Unknown Area Type     10                  10-Sistema Laguna del 7
# 9   Unknown Area Type     12          12-Sistema Bañados del R. Dulce
# 10  Unknown Area Type     14                      14-Sistema Morteros
# 11  Unknown Area Type     15                     15-Sistema A. El Ají
# ...

# %%
sa2 = f'../shapefiles/san_antonio.geojson'
san_antonio2 = gp.read_file(sa2)

# %%
san_antonio2
# Out:
#                NAME    LAYER            GM_TYPE KML_STYLE  \
# 0  Rio_SanAntonio_C  CUENCAS  Unknown Area Type     area1
#
#                                             geometry
# 0  MULTIPOLYGON (((-64.71189 -31.58140, -64.71189...

# %%
temp_sa = gp.GeoDataFrame({'LAYER': 'Unknown Area Type',
                           'Codigo': 58,
                           'Subcuenca': '58 - San Antonio',
                           'Nombre_Sub': 'San Antonio',
                           'Cuenca': 'San Antonio', 
                           'CLOSED': 'YES',
                           'BORDER_STY': 'Solid',
                           'BORDER_COL':  'RGB(0,0,0)',
                           'BORDER_WID': 1,
                           'FILL_STYLE': 'No Fill',
                           'geometry': san_antonio2['geometry']
                           })

# %%
temp_sa
# Out:
#                LAYER  Codigo         Subcuenca   Nombre_Sub       Cuenca  \
# 0  Unknown Area Type      58  58 - San Antonio  San Antonio  San Antonio
#
#   CLOSED BORDER_STY  BORDER_COL  BORDER_WID FILL_STYLE  \
# 0    YES      Solid  RGB(0,0,0)           1    No Fill
#
#                                             geometry
# 0  MULTIPOLYGON (((-64.71189 -31.58140, -64.71189...

# %%
new_cuencas = new_cuencas.append(temp_sa)

# %%
new_cuencas
# Out:
#                 LAYER Codigo                                Subcuenca  \
# 0   Unknown Area Type     01                 01-Sistema San Francisco
# 1   Unknown Area Type     02            02-Cuenca R. Quinto (Popopis)
# 2   Unknown Area Type     03                 03-Sistema A. La Punilla
# 3   Unknown Area Type     04                   04-Cuenca R. Anizacate
# 4   Unknown Area Type     05                   05-Cuenca A. La Cañada
# 5   Unknown Area Type     06                      06-Cuenca R. Saldán
# 6   Unknown Area Type     07                07-Cuenca Emb Los Molinos
# 7   Unknown Area Type     09             09-Cuenca Emb. Piedras Moras
# 8   Unknown Area Type     10                  10-Sistema Laguna del 7
# 9   Unknown Area Type     12          12-Sistema Bañados del R. Dulce
# 10  Unknown Area Type     14                      14-Sistema Morteros
# 11  Unknown Area Type     15                     15-Sistema A. El Ají
# ...

# %%
new_cuencas.to_file("")

# %%
cuencas = f'../shapefiles/cuencas.shp'
cuencas = gp.read_file(cuencas)

# %%
cuencas
# Out:
#      BORDER_COL BORDER_STY  BORDER_WID CLOSED Codigo                Cuenca  \
# 0    RGB(0,0,0)      Solid         1.0    YES     01   Río Pasaje o Salado
# 1    RGB(0,0,0)      Solid         1.0    YES     02  Río Quinto (Popopis)
# 2    RGB(0,0,0)      Solid         1.0    YES     03  Río Quinto (Popopis)
# 3    RGB(0,0,0)      Solid         1.0    YES     04     Lag. Mar Chiquita
# 4    RGB(0,0,0)      Solid         1.0    YES     05     Lag. Mar Chiquita
# ..          ...        ...         ...    ...    ...                   ...
# 101        None       None         NaN   None   None           San Antonio
# 102        None       None         NaN   None   None           San Antonio
# 103        None       None         NaN   None   None           San Antonio
# 104        None       None         NaN   None   None                  None
# 105        None       None         NaN   None   None           La Quebrada
#
# ...

# %% [markdown]
# ## 02/10/2020 NUEVO SHAPEFILE

# %%
cuencasint = '/home/sagus/Development/temp/shapefiles/cuencas_unificadas/cuencas_unificadas.shp'

# %%
cuencas = gp.read_file(cuencasint)

# %%
cuencas
# Out:
#              GM_LAYER              LAYER  Codigo  \
# 0   Unknown Area Type  Unknown Area Type    29.0
# 1   Unknown Area Type  Unknown Area Type     4.0
# 2   Unknown Area Type  Unknown Area Type     7.0
# 3   Unknown Area Type  Unknown Area Type     9.0
# 4   Unknown Area Type  Unknown Area Type    24.0
# ..                ...                ...     ...
# 85  Unknown Area Type               None     NaN
# 86  Unknown Area Type               None     NaN
# 87  Unknown Area Type               None     NaN
# 88  Unknown Area Type               None     NaN
# 89  Unknown Area Type               None     NaN
#
#                            Subcuenca                     Nombre_Sub  \
# 0   29-Sistema Salinas de Ambargasta  Sistema Salinas de Ambargasta
# 1             04-Cuenca R. Anizacate            Cuenca R. Anizacate
# 2          07-Cuenca Emb Los Molinos         Cuenca Emb Los Molinos
# 3       09-Cuenca Emb. Piedras Moras      Cuenca Emb. Piedras Moras
# ...

# %%
for cuenca in cuencas['Cuenca'].iteritems():
    print(cuenca)
# Out:
# (0, 'Lag. Mar Chiquita')
# (1, 'Lag. Mar Chiquita')
# (2, 'Lag. Mar Chiquita')
# (3, 'Río Carcarañá')
# (4, 'Salinas Grandes')
# (5, 'Salinas Grandes')
# (6, 'Salinas Grandes')
# (7, 'Salinas Grandes')
# (8, 'Salinas Grandes')
# (9, 'Salinas Grandes')
# (10, 'Salinas Grandes')
# (11, 'Salinas Grandes')
# (12, 'Salinas Grandes')
# (13, 'Lag. Mar Chiquita')
# (14, 'Salinas Grandes')
# (15, 'Salinas Grandes')
# (16, 'Salinas Grandes')
# (17, 'Salinas Grandes')
# (18, 'San Antonio')
# (19, 'Cruz del Eje')
# (20, 'Lag. Mar Chiquita')
# (21, 'Lag. Mar Chiquita')
# (22, 'La Quebrada')
# (23, 'Laguna Mar Chiquita (Mar de Ansenuza)')
# (24, 'Laguna Mar Chiquita (Mar de Ansenuza)')
# (25, 'Laguna Mar Chiquita (Mar de Ansenuza)')
# (26, 'Laguna Mar Chiquita (Mar de Ansenuza)')
# (27, 'Laguna Mar Chiquita (Mar de Ansenuza)')
# (28, 'Laguna Mar Chiquita (Mar de Ansenuza)')
# (29, 'Laguna Mar Chiquita (Mar de Ansenuza)')
# (30, 'Laguna Mar Chiquita (Mar de Ansenuza)')
# ...

# %%
cuencas.ite
# Out:
# 0     29-Sistema Salinas de Ambargasta
# 1               04-Cuenca R. Anizacate
# 2            07-Cuenca Emb Los Molinos
# 3         09-Cuenca Emb. Piedras Moras
# 4            24-Cuenca A. La Cortadera
#                     ...
# 85                                None
# 86                                None
# 87                                None
# 88                                None
# 89                                None
# Name: Subcuenca, Length: 90, dtype: object
